# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = " http://api.openweathermap.org/data/2.5/weather?q="
api_key = "&APPID=666c4dcbc13d170d764b8ea8089a36a0"
sample =[]
for city in cities:
    data = requests.get(url + city + api_key).json()
    sample.append(data)

# %%
pprint(sample)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1535588834,
#   'id': 4030556,
#   'main': {'grnd_level': 1029.74,
#            'humidity': 96,
#            'pressure': 1029.74,
#            'sea_level': 1029.71,
#            'temp': 297.162,
#            'temp_max': 297.162,
#            'temp_min': 297.162},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF',
#           'message': 0.003,
#           'sunrise': 1535641924,
#           'sunset': 1535683743},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 326.007, 'speed': 7.37}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 35.73, 'lon': 140.83},
#   'dt': 1535587200,
#   'id': 2112802,
#   'main': {'humidity': 83,
#            'pressure': 1012,
#            'temp': 301.46,
#            'temp_max': 302.15,
#            'temp_min': 301.15},
#   'name': 'Hasaki',
#   'sys': {'country': 'JP',
#           'id': 7505,
#           'message': 0.0046,
#           'sunrise': 1535573204,
#           'sunset': 1535620053,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 210, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -31.25, 'lon': -61.49},
#   'dt': 1535589047,
#   'id': 3839479,
#   'main': {'grnd_level': 1014.17,
#            'humidity': 69,
#            'pressure': 1014.17,
#            'sea_level': 1020.55,
#            'temp': 296.762,
#            'temp_max': 296.762,
#            'temp_min': 296.762},
#   'name': 'Rafaela',
#   'sys': {'country': 'AR',
#           'message': 0.0035,
#           'sunrise': 1535624672,
#           'sunset': 1535665738},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 27.0072, 'speed': 5.37}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -53.16, 'lon': -70.91},
#   'dt': 1535587200,
#   'id': 3874787,
#   'main': {'humidity': 74,
#            'pressure': 1012,
#            'temp': 274.15,
#            'temp_max': 274.15,
#            'temp_min': 274.15},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 4642,
#           'message': 0.0042,
#           'sunrise': 1535628413,
#           'sunset': 1535666546,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 5.1}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 68.75, 'lon': 161.3},
#   'dt': 1535589049,
#   'id': 2126199,
#   'main': {'grnd_level': 1023.41,
#            'humidity': 67,
#            'pressure': 1023.41,
#            'sea_level': 1031.12,
#            'temp': 284.262,
#            'temp_max': 284.262,
#            'temp_min': 284.262},
#   'name': 'Cherskiy',
#   'sys': {'country': 'RU',
#           'message': 0.0068,
#           'sunrise': 1535563625,
#           'sunset': 1535619679},
#   'weather': [{'description': 'clear sky',
#                'icon': '02d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 199.007, 'speed': 2.07}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -8.15, 'lon': 159.59},
#   'dt': 1535589051,
#   'id': 2109528,
#   'main': {'grnd_level': 1015.87,
#            'humidity': 82,
#            'pressure': 1015.87,
#            'sea_level': 1025.04,
#            'temp': 302.212,
#            'temp_max': 302.212,
#            'temp_min': 302.212},
#   'name': 'Buala',
#   'sys': {'country': 'SB',
#           'message': 0.005,
#           'sunrise': 1535570662,
#           'sunset': 1535613634},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 124.007, 'speed': 2.82}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -3.28, 'lon': -39.27},
#   'dt': 1535589054,
#   'id': 3386177,
#   'main': {'grnd_level': 1027.47,
#            'humidity': 98,
#            'pressure': 1027.47,
#            'sea_level': 1027.44,
#            'temp': 299.562,
#            'temp_max': 299.562,
#            'temp_min': 299.562},
#   'name': 'Trairi',
#   'sys': {'country': 'BR',
#           'message': 0.0047,
#           'sunrise': 1535618187,
#           'sunset': 1535661537},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 97.0072, 'speed': 9.32}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 45.76, 'lon': 8.56},
#   'dt': 1535588400,
#   'id': 3182812,
#   'main': {'humidity': 82,
#            'pressure': 1015,
#            'temp': 288.44,
#            'temp_max': 293.15,
#            'temp_min': 274.15},
#   'name': 'Arona',
#   'sys': {'country': 'IT',
#           'id': 6012,
#           'message': 0.007,
#           'sunrise': 1535604245,
#           'sunset': 1535652472,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 10, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -0.6, 'lon': 73.08},
#   'dt': 1535589058,
#   'id': 1282256,
#   'main': {'grnd_level': 1023.25,
#            'humidity': 100,
#            'pressure': 1023.25,
#            'sea_level': 1023.46,
#            'temp': 301.512,
#            'temp_max': 301.512,
#            'temp_min': 301.512},
#   'name': 'Hithadhoo',
#   'sys': {'country': 'MV',
#           'message': 0.0036,
#           'sunrise': 1535591128,
#           'sunset': 1535634678},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 358.507, 'speed': 3.42}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 61.28, 'lon': 108.01},
#   'dt': 1535589059,
#   'id': 2012956,
#   'main': {'grnd_level': 984.58,
#            'humidity': 96,
#            'pressure': 984.58,
#            'sea_level': 1023.14,
#            'temp': 286.662,
#            'temp_max': 286.662,
#            'temp_min': 286.662},
#   'name': 'Yerbogachen',
#   'rain': {'3h': 1.485},
#   'sys': {'country': 'RU',
#           'message': 0.0044,
#           'sunrise': 1535578395,
#           'sunset': 1535630545},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 245.507, 'speed': 2.12}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1535589061,
#   'id': 6201424,
#   'main': {'grnd_level': 1005.41,
#            'humidity': 95,
#            'pressure': 1005.41,
#            'sea_level': 1020.55,
#            'temp': 283.962,
#            'temp_max': 283.962,
#            'temp_min': 283.962},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'message': 0.0063,
#           'sunrise': 1535570349,
#           'sunset': 1535609533},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 271.507, 'speed': 2.47}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 6.8, 'lon': -58.16},
#   'dt': 1535587200,
#   'id': 3378644,
#   'main': {'humidity': 94,
#            'pressure': 1012,
#            'temp': 298.15,
#            'temp_max': 298.15,
#            'temp_min': 298.15},
#   'name': 'Georgetown',
#   'sys': {'country': 'GY',
#           'id': 4343,
#           'message': 0.0036,
#           'sunrise': 1535622336,
#           'sunset': 1535666445,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 36.2, 'lon': 46.09},
#   'dt': 1535589065,
#   'id': 117392,
#   'main': {'grnd_level': 827.16,
#            'humidity': 65,
#            'pressure': 827.16,
#            'sea_level': 1022.37,
#            'temp': 283.462,
#            'temp_max': 283.462,
#            'temp_min': 283.462},
#   'name': 'Mitu',
#   'sys': {'country': 'IR',
#           'message': 0.0117,
#           'sunrise': 1535595925,
#           'sunset': 1535642798},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 66.5072, 'speed': 0.77}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 56.27, 'lon': 90.5},
#   'dt': 1535589066,
#   'id': 1512165,
#   'main': {'grnd_level': 996.74,
#            'humidity': 95,
#            'pressure': 996.74,
#            'sea_level': 1027.23,
#            'temp': 284.862,
#            'temp_max': 284.862,
#            'temp_min': 284.862},
#   'name': 'Achinsk',
#   'sys': {'country': 'RU',
#           'message': 0.0049,
#           'sunrise': 1535583420,
#           'sunset': 1535633945},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 281.007, 'speed': 3.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -42.88, 'lon': 147.33},
#   'dt': 1535587200,
#   'id': 2163355,
#   'main': {'humidity': 70,
#            'pressure': 1016,
#            'temp': 280.15,
#            'temp_max': 280.15,
#            'temp_min': 280.15},
#   'name': 'Hobart',
#   'sys': {'country': 'AU',
#           'id': 8195,
#           'message': 0.0048,
#           'sunrise': 1535575272,
#           'sunset': 1535614938,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 340, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 3.3, 'lon': 117.63},
#   'dt': 1535589069,
#   'id': 1624725,
#   'main': {'grnd_level': 1025.28,
#            'humidity': 100,
#            'pressure': 1025.28,
#            'sea_level': 1025.77,
#            'temp': 297.412,
#            'temp_max': 297.412,
#            'temp_min': 297.412},
#   'name': 'Tarakan',
#   'rain': {'3h': 0.22},
#   'sys': {'country': 'ID',
#           'message': 0.0029,
#           'sunrise': 1535580288,
#           'sunset': 1535624136},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 298.507, 'speed': 2.72}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 15.34, 'lon': 74.49},
#   'dt': 1535589070,
#   'id': 1273574,
#   'main': {'grnd_level': 955.97,
#            'humidity': 98,
#            'pressure': 955.97,
#            'sea_level': 1020.99,
#            'temp': 293.862,
#            'temp_max': 293.862,
#            'temp_min': 293.862},
#   'name': 'Vaini',
#   'rain': {'3h': 6.95},
#   'sys': {'country': 'IN',
#           'message': 0.03,
#           'sunrise': 1535590156,
#           'sunset': 1535634960},
#   'weather': [{'description': 'moderate rain',
#                'icon': '10n',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 248.007, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 71.97, 'lon': 114.09},
#   'dt': 1535589072,
#   'id': 2017155,
#   'main': {'grnd_level': 998.77,
#            'humidity': 89,
#            'pressure': 998.77,
#            'sea_level': 1009.88,
#            'temp': 288.462,
#            'temp_max': 288.462,
#            'temp_min': 288.462},
#   'name': 'Saskylakh',
#   'sys': {'country': 'RU',
#           'message': 0.0028,
#           'sunrise': 1535573594,
#           'sunset': 1535632312},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 206.507, 'speed': 6.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 10.15, 'lon': -85.45},
#   'dt': 1535587200,
#   'id': 3622716,
#   'main': {'humidity': 62,
#            'pressure': 1009,
#            'temp': 303.15,
#            'temp_max': 303.15,
#            'temp_min': 303.15},
#   'name': 'Nicoya',
#   'sys': {'country': 'CR',
#           'id': 4217,
#           'message': 0.0035,
#           'sunrise': 1535628755,
#           'sunset': 1535673121,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 100, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.58, 'lon': 149.07},
#   'dt': 1535588838,
#   'id': 2175403,
#   'main': {'grnd_level': 1010.84,
#            'humidity': 28,
#            'pressure': 1010.84,
#            'sea_level': 1033.96,
#            'temp': 292.862,
#            'temp_max': 292.862,
#            'temp_min': 292.862},
#   'name': 'Bluff',
#   'sys': {'country': 'AU',
#           'message': 0.0037,
#           'sunrise': 1535573818,
#           'sunset': 1535615538},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 102.507, 'speed': 1.97}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -20.34, 'lon': 57.76},
#   'dt': 1535583600,
#   'id': 1106677,
#   'main': {'humidity': 77,
#            'pressure': 1020,
#            'temp': 291.15,
#            'temp_max': 291.15,
#            'temp_min': 291.15},
#   'name': 'Bambous Virieux',
#   'sys': {'country': 'MU',
#           'id': 6729,
#           'message': 0.0037,
#           'sunrise': 1535595579,
#           'sunset': 1535637594,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 126.007, 'speed': 3.07}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -26.79, 'lon': -60.44},
#   'dt': 1535589092,
#   'id': 3840300,
#   'main': {'grnd_level': 1009.79,
#            'humidity': 94,
#            'pressure': 1009.79,
#            'sea_level': 1020.14,
#            'temp': 293.062,
#            'temp_max': 293.062,
#            'temp_min': 293.062},
#   'name': 'Presidencia Roque Saenz Pena',
#   'rain': {'3h': 1.43},
#   'sys': {'country': 'AR',
#           'message': 0.0028,
#           'sunrise': 1535624210,
#           'sunset': 1535665693},
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 58.5072, 'speed': 1.17}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -2.92, 'lon': -39.92},
#   'dt': 1535589096,
#   'id': 3393692,
#   'main': {'grnd_level': 1020.82,
#            'humidity': 70,
#            'pressure': 1020.82,
#            'sea_level': 1026.42,
#            'temp': 299.462,
#            'temp_max': 299.462,
#            'temp_min': 299.462},
#   'name': 'Itarema',
#   'sys': {'country': 'BR',
#           'message': 0.0033,
#           'sunrise': 1535618329,
#           'sunset': 1535661707},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 73.5072, 'speed': 6.92}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.24},
#   'dt': 1535589100,
#   'id': 3366880,
#   'main': {'grnd_level': 990.42,
#            'humidity': 97,
#            'pressure': 990.42,
#            'sea_level': 1030.92,
#            'temp': 277.512,
#            'temp_max': 277.512,
#            'temp_min': 277.512},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#           'message': 0.0033,
#           'sunrise': 1535605476,
#           'sunset': 1535646195},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 92.0072, 'speed': 1.77}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': 71.98, 'lon': 102.47},
#   'dt': 1535589101,
#   'id': 2022572,
#   'main': {'grnd_level': 1009.3,
#            'humidity': 85,
#            'pressure': 1009.3,
#            'sea_level': 1013.74,
#            'temp': 282.662,
#            'temp_max': 282.662,
#            'temp_min': 282.662},
#   'name': 'Khatanga',
#   'sys': {'country': 'RU',
#           'message': 0.0035,
#           'sunrise': 1535576388,
#           'sunset': 1535635095},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 282.507, 'speed': 6.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 3.07, 'lon': 172.79},
#   'dt': 1535589103,
#   'id': 2110227,
#   'main': {'grnd_level': 1023.74,
#            'humidity': 100,
#            'pressure': 1023.74,
#            'sea_level': 1023.75,
#            'temp': 302.062,
#            'temp_max': 302.062,
#            'temp_min': 302.062},
#   'name': 'Butaritari',
#   'sys': {'country': 'KI',
#           'message': 0.0034,
#           'sunrise': 1535567060,
#           'sunset': 1535610892},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 55.0072, 'speed': 1.32}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -54.81, 'lon': -68.31},
#   'dt': 1535587200,
#   'id': 3833367,
#   'main': {'humidity': 80,
#            'pressure': 1005,
#            'temp': 272.15,
#            'temp_max': 272.15,
#            'temp_min': 272.15},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#           'id': 4754,
#           'message': 0.0047,
#           'sunrise': 1535627959,
#           'sunset': 1535665755,
#           'type': 1},
#   'visibility': 2500,
#   'weather': [{'description': 'snow',
#                'icon': '13n',
#                'id': 601,
#                'main': 'Snow'}],
#   'wind': {'deg': 230, 'gust': 12.9, 'speed': 7.7}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 58.09, 'lon': 55.86},
#   'dt': 1535585400,
#   'id': 513760,
#   'main': {'humidity': 93,
#            'pressure': 1025,
#            'temp': 287.15,
#            'temp_max': 287.15,
#            'temp_min': 287.15},
#   'name': 'Overyata',
#   'sys': {'country': 'RU',
#           'id': 7312,
#           'message': 0.0029,
#           'sunrise': 1535591479,
#           'sunset': 1535642503,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 10, 'speed': 3}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -45.87, 'lon': 170.5},
#   'dt': 1535589117,
#   'id': 2191562,
#   'main': {'grnd_level': 980.28,
#            'humidity': 86,
#            'pressure': 980.28,
#            'sea_level': 1020.34,
#            'temp': 284.412,
#            'temp_max': 284.412,
#            'temp_min': 284.412},
#   'name': 'Dunedin',
#   'sys': {'country': 'NZ',
#           'message': 0.0043,
#           'sunrise': 1535569932,
#           'sunset': 1535609163},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 274.507, 'speed': 1.62}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -21.21, 'lon': -159.78},
#   'dt': 1535587200,
#   'id': 4035715,
#   'main': {'humidity': 46,
#            'pressure': 1020,
#            'temp': 296.15,
#            'temp_max': 296.15,
#            'temp_min': 296.15},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#           'id': 8340,
#           'message': 0.0033,
#           'sunrise': 1535647794,
#           'sunset': 1535689777,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 7.7}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 66.94, 'lon': -53.67},
#   'dt': 1535589120,
#   'id': 3419842,
#   'main': {'grnd_level': 974.37,
#            'humidity': 90,
#            'pressure': 974.37,
#            'sea_level': 1010.08,
#            'temp': 275.812,
#            'temp_max': 275.812,
#            'temp_min': 275.812},
#   'name': 'Sisimiut',
#   'sys': {'country': 'GL',
#           'message': 0.0036,
#           'sunrise': 1535615941,
#           'sunset': 1535670548},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 323.007, 'speed': 0.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 56.29, 'lon': 70.46},
#   'dt': 1535589121,
#   'id': 1512210,
#   'main': {'grnd_level': 1021.87,
#            'humidity': 81,
#            'pressure': 1021.87,
#            'sea_level': 1033.88,
#            'temp': 280.262,
#            'temp_max': 280.262,
#            'temp_min': 280.262},
#   'name': 'Abatskoye',
#   'sys': {'country': 'RU',
#           'message': 0.0029,
#           'sunrise': 1535588234,
#           'sunset': 1535638749},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 228.007, 'speed': 1.82}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': 25.74, 'lon': 71.4},
#   'dt': 1535589124,
#   'id': 1276901,
#   'main': {'grnd_level': 992.2,
#            'humidity': 86,
#            'pressure': 992.2,
#            'sea_level': 1014.63,
#            'temp': 298.262,
#            'temp_max': 298.262,
#            'temp_min': 298.262},
#   'name': 'Barmer',
#   'sys': {'country': 'IN',
#           'message': 0.0041,
#           'sunrise': 1535590426,
#           'sunset': 1535636163},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 240.507, 'speed': 4.52}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 5.43, 'lon': 7.07},
#   'dt': 1535587200,
#   'id': 2337542,
#   'main': {'humidity': 94,
#            'pressure': 1012,
#            'temp': 297.15,
#            'temp_max': 297.15,
#            'temp_min': 297.15},
#   'name': 'Naze',
#   'sys': {'country': 'NG',
#           'id': 6299,
#           'message': 0.0035,
#           'sunrise': 1535606736,
#           'sunset': 1535650743,
#           'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 174.007, 'speed': 1.12}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.89, 'lon': -109.91},
#   'dt': 1535586120,
#   'id': 3985710,
#   'main': {'humidity': 62,
#            'pressure': 1013,
#            'temp': 303.15,
#            'temp_max': 303.15,
#            'temp_min': 303.15},
#   'name': 'Cabo San Lucas',
#   'sys': {'country': 'MX',
#           'id': 4016,
#           'message': 0.0032,
#           'sunrise': 1535634087,
#           'sunset': 1535679515,
#           'type': 1},
#   'visibility': 14484,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 220, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.02, 'lon': 27.91},
#   'dt': 1535589130,
#   'id': 1006984,
#   'main': {'grnd_level': 1027.71,
#            'humidity': 99,
#            'pressure': 1027.71,
#            'sea_level': 1032.38,
#            'temp': 293.362,
#            'temp_max': 293.362,
#            'temp_min': 293.362},
#   'name': 'East London',
#   'sys': {'country': 'ZA',
#           'message': 0.0119,
#           'sunrise': 1535603324,
#           'sunset': 1535644186},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 62.5072, 'speed': 5.72}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 46.19, 'lon': -82.96},
#   'dt': 1535588100,
#   'id': 5903851,
#   'main': {'humidity': 86,
#            'pressure': 1017,
#            'temp': 288.4,
#            'temp_max': 289.15,
#            'temp_min': 287.65},
#   'name': 'Blind River',
#   'sys': {'country': 'CA',
#           'id': 1403,
#           'message': 0.0064,
#           'sunrise': 1535626192,
#           'sunset': 1535674444,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 310, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 50.03, 'lon': -66.88},
#   'dt': 1535583600,
#   'id': 6111696,
#   'main': {'humidity': 82,
#            'pressure': 1011,
#            'temp': 287.15,
#            'temp_max': 287.15,
#            'temp_min': 287.15},
#   'name': 'Port-Cartier',
#   'sys': {'country': 'CA',
#           'id': 3855,
#           'message': 0.0036,
#           'sunrise': 1535621974,
#           'sunset': 1535670937,
#           'type': 1},
#   'visibility': 48279,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 30, 'speed': 2.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.59, 'lon': 26.89},
#   'dt': 1535589138,
#   'id': 964432,
#   'main': {'grnd_level': 1023.98,
#            'humidity': 94,
#            'pressure': 1023.98,
#            'sea_level': 1033.03,
#            'temp': 289.362,
#            'temp_max': 289.362,
#            'temp_min': 289.362},
#   'name': 'Port Alfred',
#   'sys': {'country': 'ZA',
#           'message': 0.006,
#           'sunrise': 1535603598,
#           'sunset': 1535644402},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 44.5072, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -33.21, 'lon': 138.6},
#   'dt': 1535588954,
#   'id': 2069194,
#   'main': {'grnd_level': 961.72,
#            'humidity': 22,
#            'pressure': 961.72,
#            'sea_level': 1019.65,
#            'temp': 291.912,
#            'temp_max': 291.912,
#            'temp_min': 291.912},
#   'name': 'Jamestown',
#   'sys': {'country': 'AU',
#           'message': 0.0044,
#           'sunrise': 1535576791,
#           'sunset': 1535617598},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 349.007, 'speed': 12.22}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.93, 'lon': 18.42},
#   'dt': 1535587200,
#   'id': 3369157,
#   'main': {'humidity': 87,
#            'pressure': 1015,
#            'temp': 286.15,
#            'temp_max': 286.15,
#            'temp_min': 286.15},
#   'name': 'Cape Town',
#   'sys': {'country': 'ZA',
#           'id': 6529,
#           'message': 0.004,
#           'sunrise': 1535605647,
#           'sunset': 1535646418,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 200, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 19.61, 'lon': 110.49},
#   'dt': 1535587200,
#   'id': 1894019,
#   'main': {'humidity': 88,
#            'pressure': 1001,
#            'temp': 300.15,
#            'temp_max': 300.15,
#            'temp_min': 300.15},
#   'name': 'Jiazi',
#   'sys': {'country': 'CN',
#           'id': 7424,
#           'message': 0.0036,
#           'sunrise': 1535581330,
#           'sunset': 1535626506,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 3}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 39.95, 'lon': -94.76},
#   'dt': 1535586780,
#   'id': 4407665,
#   'main': {'humidity': 59,
#            'pressure': 1019,
#            'temp': 297.55,
#            'temp_max': 297.55,
#            'temp_min': 297.55},
#   'name': 'Kodiak',
#   'sys': {'country': 'US',
#           'id': 1664,
#           'message': 0.0039,
#           'sunrise': 1535629503,
#           'sunset': 1535676807,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 70, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 68.06, 'lon': 166.44},
#   'dt': 1535589151,
#   'id': 2126682,
#   'main': {'grnd_level': 979.39,
#            'humidity': 68,
#            'pressure': 979.39,
#            'sea_level': 1031.57,
#            'temp': 282.512,
#            'temp_max': 282.512,
#            'temp_min': 282.512},
#   'name': 'Bilibino',
#   'sys': {'country': 'RU',
#           'message': 0.003,
#           'sunrise': 1535562629,
#           'sunset': 1535618216},
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 289.007, 'speed': 1.32}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -30.17, 'lon': -50.22},
#   'dt': 1535589153,
#   'id': 3466165,
#   'main': {'grnd_level': 1019.6,
#            'humidity': 94,
#            'pressure': 1019.6,
#            'sea_level': 1029.71,
#            'temp': 289.162,
#            'temp_max': 289.162,
#            'temp_min': 289.162},
#   'name': 'Cidreira',
#   'sys': {'country': 'BR',
#           'message': 0.0042,
#           'sunrise': 1535621917,
#           'sunset': 1535663084},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 68.5072, 'speed': 3.47}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 70.86, 'lon': 29.09},
#   'dt': 1535589156,
#   'id': 780687,
#   'main': {'grnd_level': 1012.46,
#            'humidity': 74,
#            'pressure': 1012.46,
#            'sea_level': 1030.72,
#            'temp': 286.562,
#            'temp_max': 286.562,
#            'temp_min': 286.562},
#   'name': 'Berlevag',
#   'sys': {'country': 'NO',
#           'message': 0.0031,
#           'sunrise': 1535594601,
#           'sunset': 1535652120},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 200.507, 'speed': 6.82}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -15.77, 'lon': 128.74},
#   'dt': 1535587200,
#   'id': 2068110,
#   'main': {'humidity': 51,
#            'pressure': 1013,
#            'temp': 301.15,
#            'temp_max': 301.15,
#            'temp_min': 301.15},
#   'name': 'Kununurra',
#   'sys': {'country': 'AU',
#           'id': 8215,
#           'message': 0.0037,
#           'sunrise': 1535578365,
#           'sunset': 1535620742,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 260, 'speed': 4.6}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -7.95, 'lon': 110.28},
#   'dt': 1535589160,
#   'id': 1650434,
#   'main': {'grnd_level': 996.41,
#            'humidity': 98,
#            'pressure': 996.41,
#            'sea_level': 1026.95,
#            'temp': 294.612,
#            'temp_max': 294.612,
#            'temp_min': 294.612},
#   'name': 'Bambanglipuro',
#   'rain': {'3h': 0.245},
#   'sys': {'country': 'ID',
#           'message': 0.0038,
#           'sunrise': 1535582484,
#           'sunset': 1535625475},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 157.007, 'speed': 1.92}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': 26.04, 'lon': 80.58},
#   'dt': 1535589162,
#   'id': 1275572,
#   'main': {'grnd_level': 1000.22,
#            'humidity': 98,
#            'pressure': 1000.22,
#            'sea_level': 1012.92,
#            'temp': 297.412,
#            'temp_max': 297.412,
#            'temp_min': 297.412},
#   'name': 'Bindki',
#   'rain': {'3h': 0.82},
#   'sys': {'country': 'IN',
#           'message': 0.0036,
#           'sunrise': 1535588207,
#           'sunset': 1535633976},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 296.507, 'speed': 1.77}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 69.7, 'lon': 170.27},
#   'dt': 1535589164,
#   'id': 2122090,
#   'main': {'grnd_level': 1022.36,
#            'humidity': 97,
#            'pressure': 1022.36,
#            'sea_level': 1029.46,
#            'temp': 280.862,
#            'temp_max': 280.862,
#            'temp_min': 280.862},
#   'name': 'Pevek',
#   'rain': {'3h': 0.185},
#   'sys': {'country': 'RU',
#           'message': 0.0029,
#           'sunrise': 1535561106,
#           'sunset': 1535617880},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 259.507, 'speed': 2.22}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -29.95, 'lon': -71.34},
#   'dt': 1535587200,
#   'id': 3893629,
#   'main': {'humidity': 81,
#            'pressure': 1017,
#            'temp': 285.15,
#            'temp_max': 285.15,
#            'temp_min': 285.15},
#   'name': 'Coquimbo',
#   'sys': {'country': 'CL',
#           'id': 4666,
#           'message': 0.0038,
#           'sunrise': 1535626971,
#           'sunset': 1535668165,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 22.57, 'lon': 59.53},
#   'dt': 1535589168,
#   'id': 286245,
#   'main': {'grnd_level': 984.5,
#            'humidity': 92,
#            'pressure': 984.5,
#            'sea_level': 1015.03,
#            'temp': 301.262,
#            'temp_max': 301.262,
#            'temp_min': 301.262},
#   'name': 'Sur',
#   'sys': {'country': 'OM',
#           'message': 0.0037,
#           'sunrise': 1535593427,
#           'sunset': 1535638861},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 230.507, 'speed': 4.92}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1535586960,
#   'id': 5848280,
#   'main': {'humidity': 79,
#            'pressure': 1017,
#            'temp': 302.37,
#            'temp_max': 303.15,
#            'temp_min': 301.45},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#           'id': 833,
#           'message': 0.0037,
#           'sunrise': 1535645985,
#           'sunset': 1535691330,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 29.28, 'lon': 82.18},
#   'dt': 1535589171,
#   'id': 1283285,
#   'main': {'grnd_level': 680.36,
#            'humidity': 92,
#            'pressure': 680.36,
#            'sea_level': 1016.05,
#            'temp': 276.862,
#            'temp_max': 276.862,
#            'temp_min': 276.862},
#   'name': 'Jumla',
#   'rain': {'3h': 1.335},
#   'sys': {'country': 'NP',
#           'message': 0.0053,
#           'sunrise': 1535587657,
#           'sunset': 1535633755},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 73.5072, 'speed': 1.17}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 25.02, 'lon': 37.27},
#   'dt': 1535589173,
#   'id': 100926,
#   'main': {'grnd_level': 1004.12,
#            'humidity': 100,
#            'pressure': 1004.12,
#            'sea_level': 1017.06,
#            'temp': 299.012,
#            'temp_max': 299.012,
#            'temp_min': 299.012},
#   'name': 'Umm Lajj',
#   'sys': {'country': 'SA',
#           'message': 0.0033,
#           'sunrise': 1535598654,
#           'sunset': 1535644314},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 3.50717, 'speed': 2.22}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -3.9, 'lon': -38.39},
#   'dt': 1535587200,
#   'id': 3407407,
#   'main': {'humidity': 78,
#            'pressure': 1014,
#            'temp': 299.15,
#            'temp_max': 299.15,
#            'temp_min': 299.15},
#   'name': 'Aquiraz',
#   'sys': {'country': 'BR',
#           'id': 4498,
#           'message': 0.0038,
#           'sunrise': 1535617999,
#           'sunset': 1535661303,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 90, 'speed': 6.7}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': 48.71, 'lon': 24.14},
#   'dt': 1535587200,
#   'id': 704772,
#   'main': {'humidity': 100,
#            'pressure': 1018,
#            'temp': 284.15,
#            'temp_max': 284.15,
#            'temp_min': 284.15},
#   'name': 'Lazy',
#   'sys': {'country': 'UA',
#           'id': 7360,
#           'message': 0.0046,
#           'sunrise': 1535600236,
#           'sunset': 1535648997,
#           'type': 1},
#   'visibility': 300,
#   'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#   'wind': {'deg': 112.007, 'speed': 0.87}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 38.25, 'lon': 48.3},
#   'dt': 1535589180,
#   'id': 143083,
#   'main': {'grnd_level': 838.19,
#            'humidity': 89,
#            'pressure': 838.19,
#            'sea_level': 1028.21,
#            'temp': 281.062,
#            'temp_max': 281.062,
#            'temp_min': 281.062},
#   'name': 'Ardabil',
#   'sys': {'country': 'IR',
#           'message': 0.004,
#           'sunrise': 1535595262,
#           'sunset': 1535642397},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 147.507, 'speed': 0.72}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -38.31, 'lon': -60.23},
#   'dt': 1535589181,
#   'id': 3833859,
#   'main': {'grnd_level': 1018.06,
#            'humidity': 72,
#            'pressure': 1018.06,
#            'sea_level': 1030.23,
#            'temp': 283.062,
#            'temp_max': 283.062,
#            'temp_min': 283.062},
#   'name': 'Barrow',
#   'sys': {'country': 'AR',
#           'message': 0.0031,
#           'sunrise': 1535624746,
#           'sunset': 1535665067},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 170.507, 'speed': 4.82}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 20.71, 'lon': -105.21},
#   'dt': 1535586420,
#   'id': 4004293,
#   'main': {'humidity': 74,
#            'pressure': 1010,
#            'temp': 303.15,
#            'temp_max': 303.15,
#            'temp_min': 303.15},
#   'name': 'Ixtapa',
#   'sys': {'country': 'MX',
#           'id': 4011,
#           'message': 0.0109,
#           'sunrise': 1535633057,
#           'sunset': 1535678291,
#           'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 230, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 34.35, 'lon': 131.14},
#   'dt': 1535587200,
#   'id': 1899102,
#   'main': {'humidity': 83,
#            'pressure': 1012,
#            'temp': 302.35,
#            'temp_max': 303.15,
#            'temp_min': 301.15},
#   'name': 'Nagato',
#   'sys': {'country': 'JP',
#           'id': 7534,
#           'message': 0.0035,
#           'sunrise': 1535575615,
#           'sunset': 1535622294,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -42.48, 'lon': -73.76},
#   'dt': 1535589186,
#   'id': 3896218,
#   'main': {'grnd_level': 1023.09,
#            'humidity': 85,
#            'pressure': 1023.09,
#            'sea_level': 1038.05,
#            'temp': 278.862,
#            'temp_max': 278.862,
#            'temp_min': 278.862},
#   'name': 'Castro',
#   'sys': {'country': 'CL',
#           'message': 0.003,
#           'sunrise': 1535628246,
#           'sunset': 1535668065},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 182.507, 'speed': 3.87}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 28.17, 'lon': 94.8},
#   'dt': 1535589187,
#   'id': 1278969,
#   'main': {'grnd_level': 904.82,
#            'humidity': 96,
#            'pressure': 904.82,
#            'sea_level': 1017.3,
#            'temp': 293.162,
#            'temp_max': 293.162,
#            'temp_min': 293.162},
#   'name': 'Along',
#   'rain': {'3h': 2.035},
#   'sys': {'country': 'IN',
#           'message': 0.0032,
#           'sunrise': 1535584685,
#           'sunset': 1535630672},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 47.5072, 'speed': 0.62}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 69.22, 'lon': -51.1},
#   'dt': 1535586600,
#   'id': 3423146,
#   'main': {'humidity': 69,
#            'pressure': 993,
#            'temp': 276.15,
#            'temp_max': 276.15,
#            'temp_min': 276.15},
#   'name': 'Ilulissat',
#   'sys': {'country': 'GL',
#           'id': 4805,
#           'message': 0.0038,
#           'sunrise': 1535614572,
#           'sunset': 1535670657,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 360, 'speed': 4.1}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1535587200,
#   'id': 2155415,
#   'main': {'humidity': 70,
#            'pressure': 1016,
#            'temp': 280.15,
#            'temp_max': 280.15,
#            'temp_min': 280.15},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#           'id': 8195,
#           'message': 0.0052,
#           'sunrise': 1535575330,
#           'sunset': 1535615010,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 340, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1535589195,
#   'id': 3831208,
#   'main': {'grnd_level': 983.2,
#            'humidity': 100,
#            'pressure': 983.2,
#            'sea_level': 1014.79,
#            'temp': 273.562,
#            'temp_max': 273.562,
#            'temp_min': 273.562},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL',
#           'message': 0.0036,
#           'sunrise': 1535613205,
#           'sunset': 1535680473},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 110.507, 'speed': 1.22}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -28.77, 'lon': 32.06},
#   'dt': 1535588937,
#   'id': 962367,
#   'main': {'grnd_level': 1017.01,
#            'humidity': 77,
#            'pressure': 1017.01,
#            'sea_level': 1035.34,
#            'temp': 289.612,
#            'temp_max': 289.612,
#            'temp_min': 289.612},
#   'name': 'Richards Bay',
#   'sys': {'country': 'ZA',
#           'message': 0.0038,
#           'sunrise': 1535602118,
#           'sunset': 1535643395},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 16.0072, 'speed': 4.62}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -24.32, 'lon': -47.63},
#   'dt': 1535589200,
#   'id': 3459440,
#   'main': {'grnd_level': 1025.44,
#            'humidity': 100,
#            'pressure': 1025.44,
#            'sea_level': 1033.39,
#            'temp': 291.062,
#            'temp_max': 291.062,
#            'temp_min': 291.062},
#   'name': 'Juquia',
#   'sys': {'country': 'BR',
#           'message': 0.0033,
#           'sunrise': 1535621028,
#           'sunset': 1535662725},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 69.0072, 'speed': 4.72}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 39.31, 'lon': -74.98},
#   'dt': 1535586960,
#   'id': 4501427,
#   'main': {'humidity': 76,
#            'pressure': 1015,
#            'temp': 303.2,
#            'temp_max': 304.85,
#            'temp_min': 302.05},
#   'name': 'Port Elizabeth',
#   'sys': {'country': 'US',
#           'id': 1971,
#           'message': 0.0046,
#           'sunrise': 1535624797,
#           'sunset': 1535672022,
#           'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 228.007, 'speed': 5.02}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -46.43, 'lon': -67.52},
#   'dt': 1535588905,
#   'id': 3863379,
#   'main': {'grnd_level': 1009.06,
#            'humidity': 50,
#            'pressure': 1009.06,
#            'sea_level': 1030.92,
#            'temp': 280.262,
#            'temp_max': 280.262,
#            'temp_min': 280.262},
#   'name': 'Mar del Plata',
#   'sys': {'country': 'AR',
#           'message': 0.003,
#           'sunrise': 1535627025,
#           'sunset': 1535666296},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 235.007, 'speed': 7.22}},
#  {'cod': '404', 'message': 'city not found'},
# ...
#           'id': 7518,
#           'message': 0.0036,
#           'sunrise': 1535574566,
#           'sunset': 1535621393,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 170, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.78, 'lon': -45.36},
#   'dt': 1535589931,
#   'id': 3461425,
#   'main': {'grnd_level': 1029.17,
#            'humidity': 97,
#            'pressure': 1029.17,
#            'sea_level': 1034.41,
#            'temp': 293.412,
#            'temp_max': 293.412,
#            'temp_min': 293.412},
#   'name': 'Ilhabela',
#   'sys': {'country': 'BR',
#           'message': 0.0036,
#           'sunrise': 1535620459,
#           'sunset': 1535662204},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 59.0072, 'speed': 7.92}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 57.02, 'lon': 82.07},
#   'dt': 1535589934,
#   'id': 1511057,
#   'main': {'grnd_level': 1016.12,
#            'humidity': 90,
#            'pressure': 1016.12,
#            'sea_level': 1029.91,
#            'temp': 284.962,
#            'temp_max': 284.962,
#            'temp_min': 284.962},
#   'name': 'Bakchar',
#   'sys': {'country': 'RU',
#           'message': 0.0039,
#           'sunrise': 1535585341,
#           'sunset': 1535636067},
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 281.007, 'speed': 1.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 44.83, 'lon': -0.61},
#   'dt': 1535587200,
#   'id': 3031582,
#   'main': {'humidity': 82,
#            'pressure': 1024,
#            'temp': 287.59,
#            'temp_max': 288.15,
#            'temp_min': 287.15},
#   'name': 'Saint-Augustin',
#   'sys': {'country': 'FR',
#           'id': 5525,
#           'message': 0.0051,
#           'sunrise': 1535606526,
#           'sunset': 1535654593,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 270, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 8.16, 'lon': 99.67},
#   'dt': 1535587200,
#   'id': 1150085,
#   'main': {'humidity': 100,
#            'pressure': 1009,
#            'temp': 295.15,
#            'temp_max': 295.15,
#            'temp_min': 295.15},
#   'name': 'Thung Song',
#   'sys': {'country': 'TH',
#           'id': 7951,
#           'message': 0.0034,
#           'sunrise': 1535584407,
#           'sunset': 1535628631,
#           'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 330, 'speed': 1}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 56.84, 'lon': 41.38},
#   'dt': 1535589937,
#   'id': 493231,
#   'main': {'grnd_level': 1019.44,
#            'humidity': 60,
#            'pressure': 1019.44,
#            'sea_level': 1034.33,
#            'temp': 290.262,
#            'temp_max': 290.262,
#            'temp_min': 290.262},
#   'name': 'Shuya',
#   'sys': {'country': 'RU',
#           'message': 0.0035,
#           'sunrise': 1535595146,
#           'sunset': 1535645789},
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 106.007, 'speed': 2.87}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 33.53, 'lon': 71.06},
#   'dt': 1535589000,
#   'id': 1177203,
#   'main': {'humidity': 78,
#            'pressure': 1001,
#            'temp': 301.15,
#            'temp_max': 301.15,
#            'temp_min': 301.15},
#   'name': 'Hangu',
#   'sys': {'country': 'PK',
#           'id': 7143,
#           'message': 0.004,
#           'sunrise': 1535590091,
#           'sunset': 1535636652,
#           'type': 1},
#   'visibility': 5000,
#   'weather': [{'description': 'haze',
#                'icon': '50n',
#                'id': 721,
#                'main': 'Haze'}],
#   'wind': {'deg': 310, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 53.4, 'lon': -117.57},
#   'dt': 1535589939,
#   'id': 5975503,
#   'main': {'grnd_level': 867.61,
#            'humidity': 98,
#            'pressure': 867.61,
#            'sea_level': 1016.74,
#            'temp': 282.262,
#            'temp_max': 282.262,
#            'temp_min': 282.262},
#   'name': 'Hinton',
#   'rain': {'3h': 4.58},
#   'sys': {'country': 'CA',
#           'message': 0.0031,
#           'sunrise': 1535633789,
#           'sunset': 1535683438},
#   'weather': [{'description': 'moderate rain',
#                'icon': '10n',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 179.007, 'speed': 0.87}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': -21.67, 'lon': -64.63},
#   'dt': 1535587200,
#   'id': 3903320,
#   'main': {'humidity': 35,
#            'pressure': 1014,
#            'temp': 296.15,
#            'temp_max': 296.15,
#            'temp_min': 296.15},
#   'name': 'Media Luna',
#   'sys': {'country': 'BO',
#           'id': 4440,
#           'message': 0.0076,
#           'sunrise': 1535624991,
#           'sunset': 1535666918,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 130, 'speed': 3.1}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': 40.62, 'lon': 120.71},
#   'dt': 1535589941,
#   'id': 2033766,
#   'main': {'grnd_level': 1010.2,
#            'humidity': 76,
#            'pressure': 1010.2,
#            'sea_level': 1025.49,
#            'temp': 296.012,
#            'temp_max': 296.012,
#            'temp_min': 296.012},
#   'name': 'Xingcheng',
#   'sys': {'country': 'CN',
#           'message': 0.0032,
#           'sunrise': 1535577710,
#           'sunset': 1535625196},
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 329.507, 'speed': 1.87}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -39.94, 'lon': 176.59},
#   'dt': 1535589943,
#   'id': 2185329,
#   'main': {'grnd_level': 992.85,
#            'humidity': 80,
#            'pressure': 992.85,
#            'sea_level': 1024.19,
#            'temp': 286.512,
#            'temp_max': 286.512,
#            'temp_min': 286.512},
#   'name': 'Waipawa',
#   'rain': {'3h': 0.145},
#   'sys': {'country': 'NZ',
#           'message': 0.015,
#           'sunrise': 1535568066,
#           'sunset': 1535608099},
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 79.5072, 'speed': 3.12}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 46.42, 'lon': 3.91},
#   'dt': 1535587200,
#   'id': 2980080,
#   'main': {'humidity': 87,
#            'pressure': 1023,
#            'temp': 287.15,
#            'temp_max': 287.15,
#            'temp_min': 287.15},
#   'name': 'Saint-Francois',
#   'sys': {'country': 'FR',
#           'id': 5569,
#           'message': 0.0042,
#           'sunrise': 1535605306,
#           'sunset': 1535653641,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 250, 'speed': 1.5}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 38.99, 'lon': 29.39},
#   'dt': 1535589945,
#   'id': 314716,
#   'main': {'grnd_level': 899.87,
#            'humidity': 90,
#            'pressure': 899.87,
#            'sea_level': 1025.17,
#            'temp': 285.862,
#            'temp_max': 285.862,
#            'temp_min': 285.862},
#   'name': 'Gediz',
#   'sys': {'country': 'TR',
#           'message': 0.0037,
#           'sunrise': 1535599754,
#           'sunset': 1535646978},
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 10.0072, 'speed': 1.07}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 29.56, 'lon': -104.41},
#   'dt': 1535589947,
#   'id': 3994469,
#   'main': {'grnd_level': 907.33,
#            'humidity': 33,
#            'pressure': 907.33,
#            'sea_level': 1022.45,
#            'temp': 305.862,
#            'temp_max': 305.862,
#            'temp_min': 305.862},
#   'name': 'Ojinaga',
#   'sys': {'country': 'US',
#           'message': 0.0034,
#           'sunrise': 1535632440,
#           'sunset': 1535678515},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 48.0072, 'speed': 2.57}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -20.3, 'lon': 44.28},
#   'dt': 1535589949,
#   'id': 1058381,
#   'main': {'grnd_level': 1022.52,
#            'humidity': 72,
#            'pressure': 1022.52,
#            'sea_level': 1028.33,
#            'temp': 297.762,
#            'temp_max': 297.762,
#            'temp_min': 297.762},
#   'name': 'Morondava',
#   'sys': {'country': 'MG',
#           'message': 0.0036,
#           'sunrise': 1535598810,
#           'sunset': 1535640831},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 117.507, 'speed': 4.52}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -8.57, 'lon': 32.05},
#   'dt': 1535589950,
#   'id': 156098,
#   'main': {'grnd_level': 846.21,
#            'humidity': 70,
#            'pressure': 846.21,
#            'sea_level': 1027.35,
#            'temp': 286.262,
#            'temp_max': 286.262,
#            'temp_min': 286.262},
#   'name': 'Laela',
#   'sys': {'country': 'TZ',
#           'message': 0.0035,
#           'sunrise': 1535601276,
#           'sunset': 1535644225},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 134.007, 'speed': 3.32}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 40.57, 'lon': 9.69},
#   'dt': 1535586600,
#   'id': 3166509,
#   'main': {'humidity': 78,
#            'pressure': 1016,
#            'temp': 295.15,
#            'temp_max': 295.15,
#            'temp_min': 295.15},
#   'name': 'Siniscola',
#   'sys': {'country': 'IT',
#           'id': 5788,
#           'message': 0.0045,
#           'sunrise': 1535604376,
#           'sunset': 1535651808,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 220, 'speed': 3.6}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 66.02, 'lon': 12.63},
#   'dt': 1535586600,
#   'id': 3140301,
#   'main': {'humidity': 100,
#            'pressure': 1011,
#            'temp': 286.15,
#            'temp_max': 286.15,
#            'temp_min': 286.15},
#   'name': 'Sandnessjoen',
#   'sys': {'country': 'NO',
#           'id': 5278,
#           'message': 0.0041,
#           'sunrise': 1535600254,
#           'sunset': 1535654425,
#           'type': 1},
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 240, 'speed': 4.6}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -21.69, 'lon': 165.68},
#   'dt': 1535587200,
#   'id': 2140466,
#   'main': {'humidity': 56,
#            'pressure': 1016,
#            'temp': 296.15,
#            'temp_max': 296.15,
#            'temp_min': 296.15},
#   'name': 'Moindou',
#   'sys': {'country': 'NC',
#           'id': 8344,
#           'message': 0.0048,
#           'sunrise': 1535569751,
#           'sunset': 1535611632,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 210, 'speed': 2.6}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 61.4, 'lon': 128.95},
#   'dt': 1535589956,
#   'id': 2019867,
#   'main': {'grnd_level': 998.04,
#            'humidity': 92,
#            'pressure': 998.04,
#            'sea_level': 1028.21,
#            'temp': 287.562,
#            'temp_max': 287.562,
#            'temp_min': 287.562},
#   'name': 'Mokhsogollokh',
#   'sys': {'country': 'RU',
#           'message': 0.0051,
#           'sunrise': 1535573339,
#           'sunset': 1535625551},
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 127.007, 'speed': 1.52}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 35.24, 'lon': 129.21},
#   'dt': 1535587200,
#   'id': 1842966,
#   'main': {'humidity': 83,
#            'pressure': 1011,
#            'temp': 301.15,
#            'temp_max': 301.15,
#            'temp_min': 301.15},
#   'name': 'Kijang',
#   'sys': {'country': 'KR',
#           'id': 7657,
#           'message': 0.0057,
#           'sunrise': 1535576025,
#           'sunset': 1535622809,
#           'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 220, 'speed': 4.1}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': 1.02, 'lon': 35},
#   'dt': 1535589958,
#   'id': 191220,
#   'main': {'grnd_level': 805.68,
#            'humidity': 100,
#            'pressure': 805.68,
#            'sea_level': 1024.92,
#            'temp': 285.062,
#            'temp_max': 285.062,
#            'temp_min': 285.062},
#   'name': 'Kitale',
#   'sys': {'country': 'KE',
#           'message': 0.0045,
#           'sunrise': 1535600203,
#           'sunset': 1535643876},
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 215.507, 'speed': 1.42}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 36.21, 'lon': 57.68},
#   'dt': 1535589959,
#   'id': 118063,
#   'main': {'grnd_level': 886.74,
#            'humidity': 42,
#            'pressure': 886.74,
#            'sea_level': 1026.42,
#            'temp': 287.862,
#            'temp_max': 287.862,
#            'temp_min': 287.862},
#   'name': 'Sabzevar',
#   'sys': {'country': 'IR',
#           'message': 0.0032,
#           'sunrise': 1535593141,
#           'sunset': 1535640018},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 89.0072, 'speed': 2.42}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -0.61, 'lon': -47.36},
#   'dt': 1535589960,
#   'id': 3389822,
#   'main': {'grnd_level': 1026.41,
#            'humidity': 97,
#            'pressure': 1026.41,
#            'sea_level': 1026.54,
#            'temp': 300.162,
#            'temp_max': 300.162,
#            'temp_min': 300.162},
#   'name': 'Salinopolis',
#   'sys': {'country': 'BR',
#           'message': 0.0088,
#           'sunrise': 1535620027,
#           'sunset': 1535663577},
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 75.0072, 'speed': 6.37}}]

# %%
n = 0
for city in sample:
    n += 1
    print("City number " + str(n))
# Out:
# City number 1
# City number 2
# City number 3
# City number 4
# City number 5
# City number 6
# City number 7
# City number 8
# City number 9
# City number 10
# City number 11
# City number 12
# City number 13
# City number 14
# City number 15
# City number 16
# City number 17
# City number 18
# City number 19
# City number 20
# City number 21
# City number 22
# City number 23
# City number 24
# City number 25
# City number 26
# City number 27
# City number 28
# City number 29
# City number 30
# City number 31
# City number 32
# City number 33
# City number 34
# City number 35
# City number 36
# City number 37
# City number 38
# City number 39
# City number 40
# City number 41
# City number 42
# City number 43
# City number 44
# City number 45
# City number 46
# City number 47
# City number 48
# City number 49
# City number 50
# City number 51
# City number 52
# City number 53
# City number 54
# City number 55
# City number 56
# City number 57
# City number 58
# City number 59
# City number 60
# City number 61
# City number 62
# City number 63
# City number 64
# City number 65
# City number 66
# City number 67
# City number 68
# City number 69
# City number 70
# City number 71
# City number 72
# City number 73
# City number 74
# City number 75
# City number 76
# City number 77
# City number 78
# City number 79
# City number 80
# City number 81
# City number 82
# City number 83
# City number 84
# City number 85
# City number 86
# City number 87
# City number 88
# City number 89
# City number 90
# City number 91
# City number 92
# City number 93
# City number 94
# City number 95
# City number 96
# City number 97
# City number 98
# City number 99
# City number 100
# City number 101
# City number 102
# City number 103
# City number 104
# City number 105
# City number 106
# City number 107
# City number 108
# City number 109
# City number 110
# City number 111
# City number 112
# City number 113
# City number 114
# City number 115
# City number 116
# City number 117
# City number 118
# City number 119
# City number 120
# City number 121
# City number 122
# City number 123
# City number 124
# City number 125
# City number 126
# City number 127
# City number 128
# City number 129
# City number 130
# City number 131
# City number 132
# City number 133
# City number 134
# City number 135
# City number 136
# City number 137
# City number 138
# City number 139
# City number 140
# City number 141
# City number 142
# City number 143
# City number 144
# City number 145
# City number 146
# City number 147
# City number 148
# City number 149
# City number 150
# City number 151
# City number 152
# City number 153
# City number 154
# City number 155
# City number 156
# City number 157
# City number 158
# City number 159
# City number 160
# City number 161
# City number 162
# City number 163
# City number 164
# City number 165
# City number 166
# City number 167
# City number 168
# City number 169
# City number 170
# City number 171
# City number 172
# City number 173
# City number 174
# City number 175
# City number 176
# City number 177
# City number 178
# City number 179
# City number 180
# City number 181
# City number 182
# City number 183
# City number 184
# City number 185
# City number 186
# City number 187
# City number 188
# City number 189
# City number 190
# City number 191
# City number 192
# City number 193
# City number 194
# City number 195
# City number 196
# City number 197
# City number 198
# City number 199
# City number 200
# City number 201
# City number 202
# City number 203
# City number 204
# City number 205
# City number 206
# City number 207
# City number 208
# City number 209
# City number 210
# City number 211
# City number 212
# City number 213
# City number 214
# City number 215
# City number 216
# City number 217
# City number 218
# City number 219
# City number 220
# City number 221
# City number 222
# City number 223
# City number 224
# City number 225
# City number 226
# City number 227
# City number 228
# City number 229
# City number 230
# City number 231
# City number 232
# City number 233
# City number 234
# City number 235
# City number 236
# City number 237
# City number 238
# City number 239
# City number 240
# City number 241
# City number 242
# City number 243
# City number 244
# City number 245
# City number 246
# City number 247
# City number 248
# City number 249
# City number 250
# City number 251
# City number 252
# City number 253
# City number 254
# City number 255
# City number 256
# City number 257
# City number 258
# City number 259
# City number 260
# City number 261
# City number 262
# City number 263
# City number 264
# City number 265
# City number 266
# City number 267
# City number 268
# City number 269
# City number 270
# City number 271
# City number 272
# City number 273
# City number 274
# City number 275
# City number 276
# City number 277
# City number 278
# City number 279
# City number 280
# City number 281
# City number 282
# City number 283
# City number 284
# City number 285
# City number 286
# City number 287
# City number 288
# City number 289
# City number 290
# City number 291
# City number 292
# City number 293
# City number 294
# City number 295
# City number 296
# City number 297
# City number 298
# City number 299
# City number 300
# City number 301
# City number 302
# City number 303
# City number 304
# City number 305
# City number 306
# City number 307
# City number 308
# City number 309
# City number 310
# City number 311
# City number 312
# City number 313
# City number 314
# City number 315
# City number 316
# City number 317
# City number 318
# City number 319
# City number 320
# City number 321
# City number 322
# City number 323
# City number 324
# City number 325
# City number 326
# City number 327
# City number 328
# City number 329
# City number 330
# City number 331
# City number 332
# City number 333
# City number 334
# City number 335
# City number 336
# City number 337
# City number 338
# City number 339
# City number 340
# City number 341
# City number 342
# City number 343
# City number 344
# City number 345
# City number 346
# City number 347
# City number 348
# City number 349
# City number 350
# City number 351
# City number 352
# City number 353
# City number 354
# City number 355
# City number 356
# City number 357
# City number 358
# City number 359
# City number 360
# City number 361
# City number 362
# City number 363
# City number 364
# City number 365
# City number 366
# City number 367
# City number 368
# City number 369
# City number 370
# City number 371
# City number 372
# City number 373
# City number 374
# City number 375
# City number 376
# City number 377
# City number 378
# City number 379
# City number 380
# City number 381
# City number 382
# City number 383
# City number 384
# City number 385
# City number 386
# City number 387
# City number 388
# City number 389
# City number 390
# City number 391
# City number 392
# City number 393
# City number 394
# City number 395
# City number 396
# City number 397
# City number 398
# City number 399
# City number 400
# City number 401
# City number 402
# City number 403
# City number 404
# City number 405
# City number 406
# City number 407
# City number 408
# City number 409
# City number 410
# City number 411
# City number 412
# City number 413
# City number 414
# City number 415
# City number 416
# City number 417
# City number 418
# City number 419
# City number 420
# City number 421
# City number 422
# City number 423
# City number 424
# City number 425
# City number 426
# City number 427
# City number 428
# City number 429
# City number 430
# City number 431
# City number 432
# City number 433
# City number 434
# City number 435
# City number 436
# City number 437
# City number 438
# City number 439
# City number 440
# City number 441
# City number 442
# City number 443
# City number 444
# City number 445
# City number 446
# City number 447
# City number 448
# City number 449
# City number 450
# City number 451
# City number 452
# City number 453
# City number 454
# City number 455
# City number 456
# City number 457
# City number 458
# City number 459
# City number 460
# City number 461
# City number 462
# City number 463
# City number 464
# City number 465
# City number 466
# City number 467
# City number 468
# City number 469
# City number 470
# City number 471
# City number 472
# City number 473
# City number 474
# City number 475
# City number 476
# City number 477
# City number 478
# City number 479
# City number 480
# City number 481
# City number 482
# City number 483
# City number 484
# City number 485
# City number 486
# City number 487
# City number 488
# City number 489
# City number 490
# City number 491
# City number 492
# City number 493
# City number 494
# City number 495
# City number 496
# City number 497
# City number 498
# City number 499
# City number 500
# City number 501
# City number 502
# City number 503
# City number 504
# City number 505
# City number 506
# City number 507
# City number 508
# City number 509
# City number 510
# City number 511
# City number 512
# City number 513
# City number 514
# City number 515
# City number 516
# City number 517
# City number 518
# City number 519
# City number 520
# City number 521
# City number 522
# City number 523
# City number 524
# City number 525
# City number 526
# City number 527
# City number 528
# City number 529
# City number 530
# City number 531
# City number 532
# City number 533
# City number 534
# City number 535
# City number 536
# City number 537
# City number 538
# City number 539
# City number 540
# City number 541
# City number 542
# City number 543
# City number 544
# City number 545
# City number 546
# City number 547
# City number 548
# City number 549
# City number 550
# City number 551
# City number 552
# City number 553
# City number 554
# City number 555
# City number 556
# City number 557
# City number 558
# City number 559
# City number 560
# City number 561
# City number 562
# City number 563
# City number 564
# City number 565
# City number 566
# City number 567
# City number 568
# City number 569
# City number 570
# City number 571
# City number 572
# City number 573
# City number 574
# City number 575
# City number 576
# City number 577
# City number 578
# City number 579
# City number 580
# City number 581
# City number 582
# City number 583
# City number 584
# City number 585
# City number 586
# City number 587
# City number 588
# City number 589
# City number 590
# City number 591
# City number 592
# City number 593
# City number 594
# City number 595
# City number 596
# City number 597
# City number 598
# City number 599
# City number 600
# City number 601
# City number 602
# City number 603
# City number 604
# City number 605
# City number 606
# City number 607
# City number 608
# City number 609
# City number 610
# City number 611
# City number 612
# City number 613
# City number 614
# City number 615
# City number 616
# City number 617
# City number 618
# City number 619
# City number 620
# City number 621
# City number 622
# City number 623
# City number 624
# City number 625
# City number 626
# City number 627
# City number 628
# City number 629
# City number 630
# City number 631
# City number 632
# City number 633
# City number 634
# City number 635
# City number 636

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
